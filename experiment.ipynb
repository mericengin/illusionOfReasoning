# %%
import pandas as pd

df = pd.read_csv('data/results.csv')

df.head()
# Out:
#                                            syllogism  \
# 0  All cats are mammals. All mammals are animals....
# 1  Some apples are red. All red things are sweet....
# 2  All birds have feathers. All robins are birds....
# 3  All squares are rectangles. All rectangles are...
# 4  All doctors study medicine. Surgeons are docto...
#
#                                 scrambled_syllogisms  \
# 0  All wugs are florps. All florps are daxs. Ther...
# 1  Some snarks are mimsy. All mimsy florps are zo...
# 2  All wugs have glorps. All florps are wugs. The...
# 3  All wugs are daxs. All daxs are zibbles. There...
# 4  All glorps study toma. daxs are glorps. Theref...
#
#   pred_standard_gpt-4o-mini pred_scrambled_gpt-4o-mini  \
# 0                     VALID                      VALID
# 1                     VALID                    INVALID
# 2                     VALID                      VALID
# 3                     VALID                      VALID
# ...
